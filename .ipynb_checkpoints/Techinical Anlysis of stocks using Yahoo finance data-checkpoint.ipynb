# %% [markdown]
# ## Step 1: Import Data:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from pandas.plotting import scatter_matrix

# %%
start = "2020-01-01"
end = "2023-01-01"

apple = yf.download("AAPL", start, end)
tesla = yf.download("TSLA", start, end)
amazon = yf.download("AMZN", start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Display the data:
tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# 2020-01-02  142981500
# 2020-01-03  266677500
# 2020-01-06  151995000
# ...

# %% [markdown]
# ## Step 2:
# Analyze the dataset to gather the following insights:
#
# 1. Identify the data type of each column.
# 2. Determine the total count of elements in each column.
# 3. Calculate the overall count of missing values in each column.
# 4. Compute the percentage of missing values in the dataset.

# %%
def get_stock_insights(dataframe):
    stock_insights = pd.DataFrame({
        'Datatype': dataframe.dtypes, # Data types of the columns
        'Total_Elements': dataframe.count(), # Total elements in the columns
        'Null_Count': dataframe.isnull().sum(), # Total null values inthe  columns
        'Null_Percentage': dataframe.isnull().sum() / len(dataframe) * 100 # Percentage of the null values
    })
    return stock_insights

# %%
get_stock_insights(apple)
# Out:
#           Datatype  Total_Elements  Null_Count  Null_Percentage
# Open       float64             756           0              0.0
# High       float64             756           0              0.0
# Low        float64             756           0              0.0
# Close      float64             756           0              0.0
# Adj Close  float64             756           0              0.0
# Volume       int64             756           0              0.0

# %%
get_stock_insights(tesla)
# Out:
#           Datatype  Total_Elements  Null_Count  Null_Percentage
# Open       float64             756           0              0.0
# High       float64             756           0              0.0
# Low        float64             756           0              0.0
# Close      float64             756           0              0.0
# Adj Close  float64             756           0              0.0
# Volume       int64             756           0              0.0

# %%
get_stock_insights(amazon)
# Out:
#           Datatype  Total_Elements  Null_Count  Null_Percentage
# Open       float64             756           0              0.0
# High       float64             756           0              0.0
# Low        float64             756           0              0.0
# Close      float64             756           0              0.0
# Adj Close  float64             756           0              0.0
# Volume       int64             756           0              0.0

# %% [markdown]
# Print the numerical data:

# %%
apple.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   130.231998  131.892775  128.614983  130.311812  128.737156
# std     30.596429   30.841435   30.287325   30.566496   30.684615
# min     57.020000   57.125000   53.152500   56.092499   54.848969
# 25%    115.924374  117.275000  114.129997  115.739374  113.684486
# 50%    135.794998  137.200005  133.750000  135.379997  134.161354
# 75%    150.259998  151.902504  149.029995  150.704998  149.503662
# max    182.630005  182.940002  179.119995  182.009995  180.190964
#
#              Volume
# count  7.560000e+02
# mean   1.120920e+08
# std    5.602586e+07
# min    3.519590e+07
# 25%    7.636470e+07
# 50%    9.493580e+07
# 75%    1.296327e+08
# max    4.265100e+08

# %%
tesla.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   206.595133  211.409117  201.220929  206.365502  206.365502
# std     96.049388   98.052777   93.701484   95.856975   95.856975
# min     24.980000   26.990667   23.367332   24.081333   24.081333
# 25%    138.633339  141.930000  135.544170  138.270828  138.270828
# 50%    223.964996  229.250000  218.174995  223.651665  223.651665
# 75%    278.281670  283.412506  270.410828  276.565002  276.565002
# max    411.470001  414.496674  405.666656  409.970001  409.970001
#
#              Volume
# count  7.560000e+02
# mean   1.318622e+08
# std    1.001327e+08
# min    2.940180e+07
# 25%    6.890498e+07
# 50%    9.439035e+07
# 75%    1.577763e+08
# max    9.140820e+08

# %%
amazon.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   142.561767  144.413347  140.542017  142.455482  142.455482
# std     27.932293   27.930445   27.830293   27.856019   27.856019
# min     82.075500   83.480003   81.301498   81.820000   81.820000
# 25%    118.404501  119.673622  116.074999  118.337875  118.337875
# 50%    154.873245  156.616753  151.846001  154.467499  154.467499
# 75%    164.766998  166.303131  162.958881  164.633247  164.633247
# max    187.199997  188.654007  184.839493  186.570496  186.570496
#
#              Volume
# count  7.560000e+02
# mean   8.085110e+07
# std    3.543200e+07
# min    2.903800e+07
# 25%    5.708600e+07
# 50%    7.057750e+07
# 75%    9.502950e+07
# max    3.113460e+08

# %% [markdown]
# ## Step 3: Compare Different Stocks:

# %%
# Find the average of the volume of stocks traded over time for each stock.
# convert the result into an array

apple_vol_avg = round(apple["Volume"].mean())
tesla_vol_avg = round(tesla["Volume"].mean())
amazon_vol_avg = round(amazon["Volume"].mean())

vol_avg = np.array([apple_vol_avg, tesla_vol_avg, amazon_vol_avg])
vol_avg
# Out:
# array([112092019, 131862207,  80851101])

# %% [markdown]
# ####  Get the stock with Highest Average Trading Volume: using a pie chart

# %%
my_labels = ["Apple","Tesla", "Amazon"]
my_explode = [0.2, 0, 0] 

plt.pie(vol_avg, labels = my_labels, explode = my_explode, shadow = True, autopct="%.2f")
plt.show()

# %% [markdown]
# #### Result of chart
# Tesla has Highest Average Trading Volume of the 3 famous stocks during the time period considered.

# %% [markdown]
# #### Trade Volume over time on a graph

# %%
apple['Volume'].plot(label = 'Apple', figsize = (16,8))
tesla['Volume'].plot(label = 'Tesla')
amazon['Volume'].plot(label = "Amazon")

plt.title('Volume of the Stock traded')
plt.legend()

# %% [markdown]
# From the graph we can say that apple and amazon are more consistently traded with plenty of variation. On the other hand tesla has most variations from 2020 to 2021 with significant fall in volume of stock traded.

# %% [markdown]
# #### Highest Price of Stocks Traded with Time

# %%
apple['High'].plot(label = 'Apple', figsize = (16,8))
tesla['High'].plot(label = 'Tesla')
amazon['High'].plot(label = "Amazon")

plt.title('Highest Price of Stocks Traded')
plt.legend()

# %% [markdown]
# #### Lowest Price of Stocks Traded with Time

# %%
apple['Low'].plot(label = 'Apple', figsize = (16,8))
tesla['Low'].plot(label = 'Tesla')
amazon['Low'].plot(label = "Amazon")

plt.title('Lowest Price of Stocks Traded')
plt.legend()

# %% [markdown]
# #### Open Price of Stocks Traded with Time

# %%
apple['Open'].plot(label = 'Apple', figsize = (16,8))
tesla['Open'].plot(label = 'Tesla')
amazon['Open'].plot(label = "Amazon")

plt.title('Open Price of Stocks Traded')
plt.legend()

# %% [markdown]
# ## Step 4: Market Capitalization

# %% [markdown]
# This provides the valuation of a company that is actively traded in the stock market. This enables investors to gauge the perceived worth of the company in the eyes of the investment community.
#
# The magnitude and valuation of a company indicate the potential level of risk associated with investing in its stock, as well as the possible returns over time.
#
# This valuation is derived by multiplying the total count of outstanding shares with the current price per share.
#
# Market Capitalization (M_Cap) = Total Number of Shares * Current Share Price

# %% [markdown]
# ### Identify Stocks Offering Enhanced Returns with Reduced Risk Across Time
# Ascertain the market capitalization figures for each of the three stocks and visualize the outcomes to deduce which stocks offer a combination of decreased risk and amplified returns over time.

# %%
apple['M_Cap'] = apple['Open'] * apple['Volume']
tesla['M_Cap'] = tesla['Open'] * tesla['Volume']
amazon['M_Cap'] = amazon['Open'] * amazon['Volume']

# %%
apple['M_Cap'].plot(label = 'Apple', figsize = (15,7))
tesla['M_Cap'].plot(label = 'Tesla')
amazon['M_Cap'].plot(label = 'Amazon')

plt.title('Market Cap')
plt.legend()

# %% [markdown]
# ####  Conclusion: Tesla is traded more than apple and amazon, so is we only look at the numbers than buying tesla would be safest. Also, apple is a bit safer than amazon.

# %% [markdown]
# ## Step 5: Moving Averages:

# %% [markdown]
# Utilizing Moving Averages to Address Price Fluctuations, as Stock Prices Exhibit High Volatility and Rapid Changes Over Time. Typically, an upward trajectory in a moving average (indicating a bull market) could signify an uptick in a security's price or momentum, whereas a downward trend (indicative of a bear market) might reflect a decline.
#
# We can leverage the utility of the 50-day and 200-day averages to detect trends. The 200-day moving average holds particular significance in stock trading. As long as a stock price's 50-day moving average remains higher than its 200-day moving average, the stock is generally perceived to be experiencing a bullish trend.

# %% [markdown]
# #### Determine the Stocks that Have Significant Upward Trends
#
# Find the Moving Averages for each of the three stocks and compare them to find which stocks have significant bullish trends.

# %%
# Moving avg of just one stock: apple

apple['MA50'] = apple['Open'].rolling(50).mean()
apple['MA200'] = apple['Open'].rolling(200).mean()

# Plot

apple['Open'].plot(figsize = (15,7))
apple['MA50'].plot()
apple['MA200'].plot()
plt.legend()

# %%
apple['MA50'] = apple['Open'].rolling(50).mean()
apple['MA200'] = apple['Open'].rolling(200).mean()

amazon['MA50'] = amazon['Open'].rolling(50).mean()
amazon['MA200'] = amazon['Open'].rolling(200).mean()

tesla['MA50'] = tesla['Open'].rolling(50).mean()
tesla['MA200'] = tesla['Open'].rolling(200).mean()

# %%
# plot

figure, axes = plt.subplots(2, 2, figsize = (15, 10))

figure.suptitle('Moving Averages for Apple, Tesla and Amazon')

axes[0,0].set_title('Apple')
axes[0,1].set_title('tesla')
axes[1,0].set_title('Amazon')

apple['MA50'].plot(ax=axes[0, 0])
apple['MA200'].plot(ax=axes[0, 0])
apple['Open'].plot(ax=axes[0, 0])

tesla['MA50'].plot(ax=axes[0, 1])
tesla['MA200'].plot(ax=axes[0, 1])
tesla['Open'].plot(ax=axes[0, 1])

amazon['MA50'].plot(ax=axes[1, 0])
amazon['MA200'].plot(ax=axes[1, 0])
amazon['Open'].plot(ax=axes[1, 0])
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Conclusion:
# 1. Apple has a relatively consistent upward trend, with a slight decrease towards the end before increasing again.
# 2. Tesla has a relatively consistent upward trend, with consistent decrease in 2022.
# 3. Amazon has a sharp increase, followed by a period of an almost consistent trend. There is a sharp drop towards the end before it rises again.

# %% [markdown]
# ## Step 6: Volatility and Stability

# %% [markdown]
# A percentage rise in stock value indicates the variation in stock price compared to the previous day. The magnitude of this change, whether positive or negative, directly correlates with the stock's level of volatility.
#
# The formula used is:
#
# rt = (Pt / Pt-1) - 1
#
# Where:
# - rt is the Return
# - Pt is the Price at time T
# - Pt-1 is the Price at time T-1
#
# Investors often seek stability and tend to be apprehensive about volatility.
#
# By employing histograms, we can assess whether a stock exhibits stability or volatility. A denser histogram indicates a more volatile nature of the stock.

# %% [markdown]
# #### Compare Volatility and Stability
#
# Find and compare the volatility and stability for each of the 3 stocks and determine which stock appears to be the most volatile.

# %%
apple['returns'] = (apple['Close']/apple['Close'].shift(1)) -1
tesla['returns'] = (tesla['Close']/tesla['Close'].shift(1)) -1
amazon['returns'] = (amazon['Close']/amazon['Close'].shift(1)) -1

#Draw 
figure, axes = plt.subplots(2, 2, figsize = (15, 10))

figure.suptitle('Stability and Volatility for Apple, Amazon, Ford, and Cisco')

axes[0,0].set_title('Apple')
axes[0,1].set_title('Tesla')
axes[1,0].set_title('Amazon')

apple['returns'].hist(bins = 100, label = 'Apple', alpha = 0.5, ax=axes[0, 0])

tesla['returns'].hist(bins = 100, label = 'Tesla', alpha = 0.5, ax=axes[0, 1])

amazon['returns'].hist(bins = 100, label = 'Amazon', alpha = 0.5, ax=axes[1, 0])
# Out:
# <AxesSubplot:title={'center':'Amazon'}>

# %%
# Comparing the volatility / stability for all the stocks.

apple['returns'] = (apple['Close']/apple['Close'].shift(1)) -1
tesla['returns'] = (tesla['Close']/tesla['Close'].shift(1)) -1
amazon['returns'] = (amazon['Close']/amazon['Close'].shift(1))-1

apple['returns'].hist(bins = 100, label = 'Apple', alpha = 0.5, figsize = (15,7))
tesla['returns'].hist(bins = 100, label = 'Tesla', alpha = 0.5)
amazon['returns'].hist(bins = 100, label = 'Amazon', alpha = 0.5)

plt.legend()

# %% [markdown]
# #### Conclusion:  Tesla seems to be most volatile as its histogram is thickest.

# %% [markdown]
# ## Step 7: Correlation among them:

# %%
apple_corr = apple.corr()
apple_corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999003  0.998742  0.997258   0.997201 -0.565022
# High       0.999003  1.000000  0.998609  0.998727   0.998719 -0.553469
# Low        0.998742  0.998609  1.000000  0.998780   0.998665 -0.580560
# Close      0.997258  0.998727  0.998780  1.000000   0.999914 -0.567390
# Adj Close  0.997201  0.998719  0.998665  0.999914   1.000000 -0.568377
# Volume    -0.565022 -0.553469 -0.580560 -0.567390  -0.568377  1.000000
# M_Cap      0.058822  0.071990  0.037111  0.053255   0.050602  0.737790
# MA50       0.937617  0.939778  0.935132  0.936564   0.939124 -0.534049
# MA200      0.698756  0.706799  0.692239  0.698934   0.714968 -0.234482
# returns   -0.048465 -0.027026 -0.023073  0.006375   0.005044 -0.018612
#
#               M_Cap      MA50     MA200   returns
# Open       0.058822  0.937617  0.698756 -0.048465
# High       0.071990  0.939778  0.706799 -0.027026
# ...

# %%
tesla_corr = tesla.corr()
tesla_corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.998896  0.998358  0.996724   0.996724 -0.657697
# High       0.998896  1.000000  0.998418  0.998505   0.998505 -0.648837
# Low        0.998358  0.998418  1.000000  0.998695   0.998695 -0.667700
# Close      0.996724  0.998505  0.998695  1.000000   1.000000 -0.656405
# Adj Close  0.996724  0.998505  0.998695  1.000000   1.000000 -0.656405
# Volume    -0.657697 -0.648837 -0.667700 -0.656405  -0.656405  1.000000
# M_Cap      0.343774  0.357312  0.324046  0.342673   0.342673  0.300335
# MA50       0.911948  0.913080  0.907404  0.908230   0.908230 -0.671858
# MA200      0.439731  0.443321  0.434439  0.433136   0.433136 -0.279906
# returns   -0.088094 -0.064362 -0.059882 -0.033150  -0.033150  0.148433
#
#               M_Cap      MA50     MA200   returns
# Open       0.343774  0.911948  0.439731 -0.088094
# High       0.357312  0.913080  0.443321 -0.064362
# ...

# %%
amazon_corr = amazon.corr()
amazon_corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.998359  0.998037  0.995749   0.995749 -0.238781
# High       0.998359  1.000000  0.997842  0.998053   0.998053 -0.222685
# Low        0.998037  0.997842  1.000000  0.998181   0.998181 -0.257536
# Close      0.995749  0.998053  0.998181  1.000000   1.000000 -0.239569
# Adj Close  0.995749  0.998053  0.998181  1.000000   1.000000 -0.239569
# Volume    -0.238781 -0.222685 -0.257536 -0.239569  -0.239569  1.000000
# M_Cap      0.255272  0.270752  0.233991  0.251635   0.251635  0.854348
# MA50       0.880897  0.881136  0.877295  0.877106   0.877106 -0.209824
# MA200      0.623493  0.630819  0.619697  0.625262   0.625262 -0.107478
# returns   -0.003092  0.027139  0.030349  0.065152   0.065152  0.003082
#
#               M_Cap      MA50     MA200   returns
# Open       0.255272  0.880897  0.623493 -0.003092
# High       0.270752  0.881136  0.630819  0.027139
# ...

# %% [markdown]
# ### Use heatmaps to visualize correlation:

# %%
sns.heatmap(apple_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tesla_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(amazon_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Conclusion: Volume is negatively correlated to all columns except return of the stocks but it is least negeatively correlated to amazon stock.

# %% [markdown]
# ## Step 8: Final conclusion of analysis:

# %% [markdown]
# ####  For the time period on which this data is analyzed apple seems to be the best options considering all the above points.
